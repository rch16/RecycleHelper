# %%
import numpy as np
import matplotlib.pyplot as plt
import coremltools
import lime
import IProgress
import tqdm
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-78-d97d03280fd3> in <module>
#       3 import coremltools
#       4 import lime
# ----> 5 import IProgress
#       6 import tqdm
#
# ModuleNotFoundError: No module named 'IProgress'

# %%
from PIL import Image
from lime import lime_image
from ipywidgets import IntProgress as IProgress

# %% [markdown]
# ### Import Model & Test Images

# %%
model_path = 'WasteClassifier.mlmodel'

img_path1 = 'plastic32.jpg'
img_path2 = 'cardboard85.jpg'
img_path3 = 'metal349.jpg'

# %%
# dictionary of label strings to numbers
class_labels = {'cardboard': 1,
                'paper': 2,
                'glass': 3,
                'plastic': 4,
                'trash': 5,
                'metal': 6}

# %%
img1 = Image.open(img_path1)
img2 = Image.open(img_path2)
img3 = Image.open(img_path3)

# %%
model = coremltools.models.MLModel(path)

# %% [markdown]
# ## LIME Analysis

# %%
# create lime explanation for prediction
explainer = lime_image.LimeImageExplainer(verbose=True)

# %%
#image class prediction function
def class_pred(image_array):
    # convert array back to PIL Image
    image = Image.fromarray(np.uint8(img))
    
    # get predictions for each image
    predictions = model.predict({'image': image}) 
    
    # obtain prediction for each class
    p = predictions['classLabelProbs']
    
    # convert into array of tuples
    pred_list = [(class_labels[key],value) for key,value in p.items()] # return array
    
    return pred_list

# %% [markdown]
# ### Test Image 1

# %%
plt.imshow(np.asarray(img1))

# %%
pred1 = model.predict({'image':img1})
print(pred1)
# Out:
# {'classLabelProbs': {'cardboard': 6.9276662604019296e-18, 'paper': 8.271752659117591e-23, 'glass': 1.3931493118473968e-05, 'plastic': 0.9999860685068815, 'trash': 4.8109540581374524e-24, 'metal': 3.8873121654066157e-17}, 'classLabel': 'plastic'}

# %%
label1 = pred1['classLabel']
print(label1)
# Out:
# plastic

# %% [markdown]
# As can be seen, the model outputs the correct prediction for image 1.

# %%
# Generate array of probabilities of image belonging to each class
p = pred1['classLabelProbs']
pred_list = [(class_labels[key],value) for key,value in p.items()] 
print(pred_list)
# Out:
# [(1, 6.9276662604019296e-18), (2, 8.271752659117591e-23), (3, 1.3931493118473968e-05), (4, 0.9999860685068815), (5, 4.8109540581374524e-24), (6, 3.8873121654066157e-17)]

# %%
explanation = explainer.explain_instance(np.array(img1), pred_list, num_samples=6, hide_color=0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Library/Python/3.7/site-packages/tqdm/notebook.py in status_printer(_, total, desc, ncols)
#      95             if total:
# ---> 96                 pbar = IProgress(min=0, max=total)
#      97             else:  # No total? Show info style bar with no progress tqdm status
#
# NameError: name 'IProgress' is not defined
#
# During handling of the above exception, another exception occurred:
#
# ImportError                               Traceback (most recent call last)
# <ipython-input-74-e56c4879ae8b> in <module>
# ----> 1 explanation = explainer.explain_instance(np.array(img1), pred_list, num_samples=6, hide_color=0)
#
# /Library/Python/3.7/site-packages/lime/lime_image.py in explain_instance(self, image, classifier_fn, labels, hide_color, top_labels, num_features, num_samples, batch_size, segmentation_fn, distance_metric, model_regressor, random_seed)
#     198         data, labels = self.data_labels(image, fudged_image, segments,
#     199                                         classifier_fn, num_samples,
# --> 200                                         batch_size=batch_size)
#     201
#     202         distances = sklearn.metrics.pairwise_distances(
#
# /Library/Python/3.7/site-packages/lime/lime_image.py in data_labels(self, image, fudged_image, segments, classifier_fn, num_samples, batch_size)
#     250         data[0, :] = 1
#     251         imgs = []
# --> 252         for row in tqdm(data):
#     253             temp = copy.deepcopy(image)
#     254             zeros = np.where(row == 0)[0]
#
# /Library/Python/3.7/site-packages/tqdm/notebook.py in __init__(self, *args, **kwargs)
#     207         total = self.total * unit_scale if self.total else self.total
#     208         self.container = self.status_printer(
# --> 209             self.fp, total, self.desc, self.ncols)
#     210         self.sp = self.display
#     211
#
# /Library/Python/3.7/site-packages/tqdm/notebook.py in status_printer(_, total, desc, ncols)
#     102             # #187 #451 #558
#     103             raise ImportError(
# --> 104                 "FloatProgress not found. Please update jupyter and ipywidgets."
#     105                 " See https://ipywidgets.readthedocs.io/en/stable"
#     106                 "/user_install.html")
#
# ImportError: FloatProgress not found. Please update jupyter and ipywidgets. See https://ipywidgets.readthedocs.io/en/stable/user_install.html

# %% [markdown]
# ### Test Image 2

# %%
pred2 = model.predict({'image':img2})

# %% [markdown]
# ### Test Image 3

# %%
pred3 = model.predict({'image':img3})
